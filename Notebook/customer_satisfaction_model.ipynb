# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("mark.csv")

# %%
data.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %%
data
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data.shape
# Out:
# (103904, 25)

# %%
data.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
data['Gender'].value_counts()
# Out:
# Female    52727
# Male      51177
# Name: Gender, dtype: int64

# %%
data['Customer Type'].value_counts()
# Out:
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64

# %%
data['Type of Travel'].value_counts()
# Out:
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64

# %%
data['Class'].value_counts()
# Out:
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103904, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, Gender, Customer Type, Age, Type of Travel, Class, Flight Distance, Inflight wifi service, Departure/Arrival time convenient, Ease of Online booking, Gate location, Food and drink, Online boarding, Seat comfort, Inflight entertainment, On-board service, Leg room service, Baggage handling, Checkin service, Inflight service, Cleanliness, Departure Delay in Minutes, Arrival Delay in Minutes, satisfaction]
# Index: []
#
# [0 rows x 25 columns]

# %%
data.duplicated().sum()
# no duplicate rows
# Out:
# 0

# %%
data['Arrival Delay in Minutes'].isnull().sum()
# Out:
# 310

# %%
data['Food and drink'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
data[data['Arrival Delay in Minutes'].isnull()]
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 213            213   49608  Female     Loyal Customer   38  Business travel
# 1124          1124   73442    Male     Loyal Customer   53  Personal Travel
# 1529          1529   71178    Male     Loyal Customer   39  Business travel
# 2004          2004   72940  Female  disloyal Customer   26  Business travel
# 2108          2108  116374  Female     Loyal Customer   24  Personal Travel
# ...            ...     ...     ...                ...  ...              ...
# 102067      102067   36729    Male     Loyal Customer   49  Personal Travel
# 102384      102384   71241    Male     Loyal Customer   58  Business travel
# 102552      102552   27684  Female  disloyal Customer   29  Business travel
# 102960      102960   36787    Male     Loyal Customer   58  Business travel
# 103540      103540   45022  Female     Loyal Customer   33  Personal Travel
#
# ...

# %%
data['Arrival Delay in Minutes'].fillna(0)
# converted NaN to 0
# Out:
# 0         18.0
# 1          6.0
# 2          0.0
# 3          9.0
# 4          0.0
#           ...
# 103899     0.0
# 103900     0.0
# 103901    14.0
# 103902     0.0
# 103903     0.0
# Name: Arrival Delay in Minutes, Length: 103904, dtype: float64

# %%
data['Arrival Delay in Minutes'] = data['Arrival Delay in Minutes'].fillna(0)

# %%
data
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
data.drop(columns = 'Unnamed: 0', inplace = True)
# removed 'Unnamed: 0' column as it is not necessary

# %%
data
# Out:
#             id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0        70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         5047    Male  disloyal Customer   25  Business travel  Business
# 2       110028  Female     Loyal Customer   26  Business travel  Business
# 3        24026  Female     Loyal Customer   25  Business travel  Business
# 4       119299    Male     Loyal Customer   61  Business travel  Business
# ...        ...     ...                ...  ...              ...       ...
# 103899   94171  Female  disloyal Customer   23  Business travel       Eco
# 103900   73097    Male     Loyal Customer   49  Business travel  Business
# 103901   68825    Male  disloyal Customer   30  Business travel  Business
# 103902   54173  Female  disloyal Customer   22  Business travel       Eco
# 103903   62567    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
# ...

# %% [markdown]
# ## EDA(Exploratory Data Analysis) and Data Visualisation

# %%
data['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
data['Customer Type'].value_counts()
# Out:
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64

# %%
labels = ['neutral or dissatisfied','satisfied']
colors = ['#3787C0', '#B1C9BB']
sns.set_style('whitegrid')
plt.pie(data['satisfaction'].value_counts(), labels = labels, autopct = '%1.1f%%', colors = colors)
plt.title('Satisfaction Rate', fontdict={'weight': 'bold'})
plt.legend()
plt.show()

# %% [markdown]
# ##### ==> Around 56.7% of passengers are dissatisfied with the service and only 43.3% are satisfied

# %%
grouped_data = data.groupby(['satisfaction', 'Gender']).size()

# %%
data.groupby(['satisfaction', 'Gender']).size()
# Out:
# satisfaction             Gender
# neutral or dissatisfied  Female    30193
#                          Male      28686
# satisfied                Female    22534
#                          Male      22491
# dtype: int64

# %%
fig, ax = plt.subplots()
labels = ['neutral or dissatisfied','satisfied']
inner_labels = [f' {gender}' for satisfaction, gender in grouped_data.index]
colors = ['#3787C0', '#B1C9BB']
colors1 = ['#9AC7E0', '#9AC7E0', '#CFDED5', '#CFDED5']
ax.pie(data['satisfaction'].value_counts().sort_index(), labels = labels, radius = 1, colors = colors, wedgeprops=dict(width = 0.3, edgecolor = 'w'))
ax.pie(grouped_data.values,labels = inner_labels, radius = 0.7,colors = colors1, wedgeprops=dict(width = 0.3, edgecolor = 'w'), autopct='%1.1f%%')
plt.title('Satisfaction Rate grouped with Gender', fontdict={'weight': 'bold'})
plt.show()

# %%
data.groupby(['satisfaction', 'Gender']).size()
# Out:
# satisfaction             Gender
# neutral or dissatisfied  Female    30193
#                          Male      28686
# satisfied                Female    22534
#                          Male      22491
# dtype: int64

# %%
p = sns.countplot(data = data, x = 'satisfaction', palette= 'YlGn', hue='Gender')
plt.xlabel('Satisfaction')
plt.ylabel('Count of passenegers')
for container in p.containers:
    plt.bar_label(container)
plt.show()

# %%
data.groupby(['satisfaction', 'Customer Type']).size()
# Out:
# satisfaction             Customer Type
# neutral or dissatisfied  Loyal Customer       44390
#                          disloyal Customer    14489
# satisfied                Loyal Customer       40533
#                          disloyal Customer     4492
# dtype: int64

# %%
p = sns.countplot(data = data, x = 'satisfaction',palette= 'YlGn', hue='Customer Type')
plt.xlabel('Satisfaction')
plt.ylabel('Count of passenegers')
for container in p.containers:
    plt.bar_label(container)
plt.show()

# %%
data.groupby(['satisfaction', 'Class']).size()
# Out:
# satisfaction             Class
# neutral or dissatisfied  Business    15185
#                          Eco         38044
#                          Eco Plus     5650
# satisfied                Business    34480
#                          Eco          8701
#                          Eco Plus     1844
# dtype: int64

# %%
p = sns.countplot(data = data, x = 'satisfaction',palette= 'YlGn', hue='Class')
plt.xlabel('Satisfaction')
plt.ylabel('Count of passenegers')
for container in p.containers:
    plt.bar_label(container)
plt.show()

# %%
order = data['satisfaction'].value_counts().index
plot = sns.FacetGrid(data, col = 'Class')
p = plot.map(sns.countplot, 'satisfaction', order = order, palette = 'YlGn')

# %%
data['Departure Delay in Minutes'].value_counts().size
# Out:
# 446

# %% [markdown]
# ### Arrival Delay analysis in Minutes

# %%
data['Arrival Delay in Minutes'].describe()
# Out:
# count    103904.000000
# mean         15.133392
# std          38.649776
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          13.000000
# max        1584.000000
# Name: Arrival Delay in Minutes, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.kdeplot( x = data['Arrival Delay in Minutes'], fill = True, color = 'blue')
# Out:
# <Axes: xlabel='Arrival Delay in Minutes', ylabel='Density'>

# %%
sns.boxplot(y = data['Arrival Delay in Minutes'])
# Out:
# <Axes: ylabel='Arrival Delay in Minutes'>

# %%
sns.violinplot(y = data['Arrival Delay in Minutes'])
# Out:
# <Axes: ylabel='Arrival Delay in Minutes'>

# %%
data['Arrival Delay in Minutes'].mode()
# Out:
# 0    0.0
# Name: Arrival Delay in Minutes, dtype: float64

# %% [markdown]
# ### Departure Delay analysis in Minutes

# %%
data['Departure Delay in Minutes'].describe()
# Out:
# count    103904.000000
# mean         14.815618
# std          38.230901
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          12.000000
# max        1592.000000
# Name: Departure Delay in Minutes, dtype: float64

# %%
plt.figure(figsize=(20,10))
sns.kdeplot( x = data['Departure Delay in Minutes'], fill = True, color = 'blue')
# Out:
# <Axes: xlabel='Departure Delay in Minutes', ylabel='Density'>

# %%
sns.boxplot(y = data['Departure Delay in Minutes'])
# Out:
# <Axes: ylabel='Departure Delay in Minutes'>

# %%
sns.violinplot(y = data['Departure Delay in Minutes'])
# Out:
# <Axes: ylabel='Departure Delay in Minutes'>

# %%
data['Arrival Delay in Minutes'].mode()
# Out:
# 0    0.0
# Name: Arrival Delay in Minutes, dtype: float64

# %%
data = data.drop(columns = ['id'])

# %%
data.columns
# Out:
# Index(['Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %% [markdown]
# # Categories

# %% [markdown]
# ## 1. Booking and pre-flight services

# %% [markdown]
# ##### - Ease of Online booking
# ##### - Checkin service
# ##### - Gate location

# %% [markdown]
# ## 2. Flight Timing and Schedule

# %% [markdown]
# ##### - Departure/Arrival time convenient

# %% [markdown]
# ## 3. Onboard Comfort and Amenities

# %% [markdown]
# ##### - Inflight wifi service
# ##### - Food and drink
# ##### - Seat comfort
# ##### - Inflight entertainment
# ##### - Leg room service

# %% [markdown]
# ## 4. Onboard Service Quality

# %% [markdown]
# ##### - On-board service
# ##### - Inflight service
# ##### - Cleanliness

# %% [markdown]
# ## 5. Baggage and Ground Services

# %% [markdown]
# ##### - Baggage handling

# %% [markdown]
# ## 6. Boarding Process

# %% [markdown]
# ##### - Online boarding

# %%
fig, axes = plt.subplots(2,2, figsize=(10,10))
fig.suptitle('Booking and pre-flight services', fontsize = 20)
sns.countplot( x = data['Ease of Online booking'],ax=axes[0,0], palette = 'mako')
sns.countplot(x = data['Checkin service'],ax=axes[0,1], palette = 'mako')
sns.countplot(x = data['Gate location'],ax=axes[1,0], palette = 'mako')
axes[1,1].remove()
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1,1, figsize=(5,5))
fig.suptitle('Flight Timing and Schedule', fontsize = 20, ha= 'center')
sns.countplot( x = data['Departure/Arrival time convenient'],palette = 'mako')
plt.tight_layout()
plt.show()

# %%
data.groupby(['Departure/Arrival time convenient']).size()
# Out:
# Departure/Arrival time convenient
# 0     5300
# 1    15498
# 2    17191
# 3    17966
# 4    25546
# 5    22403
# dtype: int64

# %%
fig, axes = plt.subplots(3,2, figsize=(10,10))
fig.suptitle('Onboard Comfort and Amenities', fontsize = 20)
sns.countplot(x = data['Inflight wifi service'],ax=axes[0,0],palette = 'mako')
sns.countplot(x = data['Food and drink'],ax=axes[0,1],palette = 'mako')
sns.countplot(x = data['Seat comfort'],ax=axes[1,0],palette = 'mako')
sns.countplot(x = data['Inflight entertainment'],ax=axes[1,1],palette = 'mako')
sns.countplot(x = data['Leg room service'],ax=axes[2,0],palette = 'mako')
axes[2,1].remove()
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,2, figsize=(10,10))
fig.suptitle('Onboard Service Quality', fontsize = 20)
sns.countplot(x = data['On-board service'],ax=axes[0,0],palette = 'mako')
sns.countplot(x = data['Inflight service'],ax=axes[0,1],palette = 'mako')
sns.countplot(x = data['Cleanliness'],ax=axes[1,0],palette = 'mako')
axes[1,1].remove()
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1,1, figsize=(5,5))
fig.suptitle('Baggage and Ground Services', fontsize = 20)
sns.countplot(x = data['Baggage handling'],palette = 'mako')
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1,1, figsize=(5,5))
fig.suptitle('Boarding Process', fontsize = 20)
sns.countplot(x = data['Online boarding'],palette = 'mako')
plt.tight_layout()
plt.show()

# %%
sns.kdeplot(x= data['Online boarding'], hue = data['satisfaction'], fill = True)
# Out:
# <Axes: xlabel='Online boarding', ylabel='Density'>

# %%
sns.scatterplot(x= data['Online boarding'], y = data['satisfaction'], hue = data['satisfaction'])
# Out:
# <Axes: xlabel='Online boarding', ylabel='satisfaction'>

# %%
obj_data = data.select_dtypes(include = 'object')
obj_data
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction
# 0       neutral or dissatisfied
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 4                     satisfied
# ...                         ...
# ...

# %%
la = LabelEncoder()
cols = ['Gender', 'Customer Type', 'Type of Travel']
for col in cols:  #converting categorical values into numerical values using label encoder
    data[col] = la.fit_transform(data[col])

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder(categories=[['Eco', 'Eco Plus', 'Business']])
data['Class'] = oe.fit_transform(data[['Class']])

oe = OrdinalEncoder(categories=[[ 'neutral or dissatisfied','satisfied']])
data['satisfaction'] = oe.fit_transform(data[['satisfaction']])

# %%
data
# Out:
#         Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0            1              0   13               1    1.0              460
# 1            1              1   25               0    2.0              235
# 2            0              0   26               0    2.0             1142
# 3            0              0   25               0    2.0              562
# 4            1              0   61               0    2.0              214
# ...        ...            ...  ...             ...    ...              ...
# 103899       0              1   23               0    0.0              192
# 103900       1              0   49               0    2.0             2347
# 103901       1              1   30               0    2.0             1995
# 103902       0              1   22               0    0.0             1000
# 103903       1              0   27               0    2.0             1723
#
#         Inflight wifi service  Departure/Arrival time convenient  \
# ...

# %% [markdown]
# ### Analysing the correlation between satisfaction rate and services provided

# %%
data.corr()['satisfaction'].sort_values(ascending = False) #checking the correlation between all colums and satisfaction
# Out:
# satisfaction                         1.000000
# Online boarding                      0.503557
# Class                                0.494471
# Inflight entertainment               0.398059
# Seat comfort                         0.349459
# On-board service                     0.322383
# Leg room service                     0.313131
# Cleanliness                          0.305198
# Flight Distance                      0.298780
# Inflight wifi service                0.284245
# Baggage handling                     0.247749
# Inflight service                     0.244741
# Checkin service                      0.236174
# Food and drink                       0.209936
# Ease of Online booking               0.171705
# Age                                  0.137167
# Gender                               0.012211
# Gate location                        0.000682
# Departure Delay in Minutes          -0.050494
# Departure/Arrival time convenient   -0.051601
# ...

# %%
data['Online boarding']
# Out:
# 0         3
# 1         3
# 2         5
# 3         2
# 4         5
#          ..
# 103899    2
# 103900    4
# 103901    1
# 103902    1
# 103903    1
# Name: Online boarding, Length: 103904, dtype: int64

# %%
mask = np.triu(np.ones_like(data.corr(), dtype=bool))
sns.set(style = 'white')
sns.heatmap(data= data.corr(),linewidths=0.5, mask = mask)
# Out:
# <Axes: >

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x = data.iloc[:, :-1]
y = data.iloc[:, -1]

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,test_size=0.2)

# %%
print(len(y_train[y_train==1]))
print(len(y_train[y_train==0]))
# Out:
# 36068
# 47055

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
x_test
# Out:
# array([[ 1.01503056, -0.4727667 ,  0.63647788, ...,  1.30586973,
#          1.52192757,  1.96293434],
#        [-0.98519201,  2.11520819,  2.68743545, ..., -0.98025121,
#          1.2603578 ,  0.82450053],
#        [-0.98519201, -0.4727667 ,  0.30567827, ..., -0.2182109 ,
#         -0.3875318 , -0.39155376],
#        ...,
#        [ 1.01503056, -0.4727667 ,  0.37183819, ...,  0.54382941,
#         -0.3875318 , -0.39155376],
#        [ 1.01503056, -0.4727667 , -0.88520032, ..., -0.2182109 ,
#         -0.3875318 , -0.39155376],
#        [ 1.01503056, -0.4727667 ,  1.43039694, ..., -1.74229153,
#         -0.3875318 , -0.39155376]])

# %%
print(type(x_test))
# Out:
# <class 'numpy.ndarray'>

# %%
y_predict = knn.predict(x_test)

# %%
knn.predict_proba(x_test)
# Out:
# array([[0. , 1. ],
#        [0.4, 0.6],
#        [0. , 1. ],
#        ...,
#        [0.2, 0.8],
#        [1. , 0. ],
#        [1. , 0. ]])

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.97      0.94     11824
#          1.0       0.95      0.88      0.91      8957
#
#     accuracy                           0.93     20781
#    macro avg       0.93      0.92      0.93     20781
# weighted avg       0.93      0.93      0.93     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[11433,   391],
#        [ 1102,  7855]], dtype=int64)

# %%
from sklearn.model_selection import cross_val_score, KFold
kf = KFold(n_splits=10, shuffle=True)
cross_val_results = cross_val_score(knn, x, y , cv=kf)
print(f'accuracy of all 10 folds: {cross_val_results}')
print(f'mean accuracy: {cross_val_results.mean()}')
# Out:
# accuracy of all 10 folds: [0.92378019 0.92888076 0.92868829 0.93051679 0.92637151 0.92685274
#  0.93031761 0.92858518 0.93455245 0.92791145]
# mean accuracy: 0.9286456990756697

# %% [markdown]
# ## Naive bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_predict = gnb.predict(x_test)

# %%
gnb.predict_proba(x_test)
# Out:
# array([[2.59158224e-04, 9.99740842e-01],
#        [5.14514730e-01, 4.85485270e-01],
#        [5.22818605e-05, 9.99947718e-01],
#        ...,
#        [7.19518648e-01, 2.80481352e-01],
#        [9.99973544e-01, 2.64562064e-05],
#        [9.99999998e-01, 1.84087847e-09]])

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.90      0.88     11824
#          1.0       0.86      0.82      0.84      8957
#
#     accuracy                           0.86     20781
#    macro avg       0.86      0.86      0.86     20781
# weighted avg       0.86      0.86      0.86     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[10637,  1187],
#        [ 1629,  7328]], dtype=int64)

# %%
cross_val_results = cross_val_score(gnb, x, y , cv=kf)
print(f'accuracy of all 10 folds: {cross_val_results}')
print(f'mean accuracy: {cross_val_results.mean()}')
# Out:
# accuracy of all 10 folds: [0.86748147 0.86170725 0.8631508  0.86228467 0.86737247 0.8653513
#  0.8641001  0.86227141 0.87122233 0.86794995]
# mean accuracy: 0.8652891758980366

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# #### Using Ridge Regularization

# %%
lr = LogisticRegression(penalty='l2', C=1.0, solver='liblinear')

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
y_predict = lr.predict(x_test)

# %%
lr.predict_proba(x_test)
# Out:
# array([[0.11006848, 0.88993152],
#        [0.6199613 , 0.3800387 ],
#        [0.07106463, 0.92893537],
#        ...,
#        [0.73428697, 0.26571303],
#        [0.97763235, 0.02236765],
#        [0.99530153, 0.00469847]])

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89     11824
#          1.0       0.87      0.83      0.85      8957
#
#     accuracy                           0.87     20781
#    macro avg       0.87      0.87      0.87     20781
# weighted avg       0.87      0.87      0.87     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[10689,  1135],
#        [ 1497,  7460]], dtype=int64)

# %%
cross_val_results = cross_val_score(lr, x, y , cv=kf)
print(f'accuracy of all 10 folds: {cross_val_results}')
print(f'mean accuracy: {cross_val_results.mean()}')
# Out:
# accuracy of all 10 folds: [0.8792224  0.87421807 0.87383312 0.87518044 0.87141482 0.87767084
#  0.87045236 0.8773821  0.87507218 0.87362849]
# mean accuracy: 0.874807483599165

# %% [markdown]
# #### Using Lasso Regularization

# %%
lr = LogisticRegression(penalty='l1', C=1.0, solver='liblinear')
lr.fit(x_train, y_train)
y_predict = lr.predict(x_test)
lr.predict_proba(x_test)
# Out:
# array([[0.10947181, 0.89052819],
#        [0.62103824, 0.37896176],
#        [0.07111637, 0.92888363],
#        ...,
#        [0.73424478, 0.26575522],
#        [0.97764073, 0.02235927],
#        [0.99529941, 0.00470059]])

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.90      0.89     11824
#          1.0       0.87      0.83      0.85      8957
#
#     accuracy                           0.87     20781
#    macro avg       0.87      0.87      0.87     20781
# weighted avg       0.87      0.87      0.87     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[10689,  1135],
#        [ 1496,  7461]], dtype=int64)

# %%
cross_val_results = cross_val_score(lr, x, y , cv=kf)
print(f'accuracy of all 10 folds: {cross_val_results}')
print(f'mean accuracy: {cross_val_results.mean()}')
# Out:
# accuracy of all 10 folds: [0.86892503 0.87595034 0.87450678 0.87450678 0.8732435  0.86756497
#  0.87930703 0.8759384  0.87487969 0.88180943]
# mean accuracy: 0.874663196449063

# %% [markdown]
# ## Support vector machine

# %%
from sklearn.svm import SVC

# %%
supportvm = SVC()

# %%
supportvm.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_predict = supportvm.predict(x_test)

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.97      0.96     11824
#          1.0       0.96      0.93      0.95      8957
#
#     accuracy                           0.95     20781
#    macro avg       0.95      0.95      0.95     20781
# weighted avg       0.95      0.95      0.95     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[11452,   372],
#        [  599,  8358]], dtype=int64)

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = dtc.predict(x_test)

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     11824
#          1.0       0.93      0.94      0.94      8957
#
#     accuracy                           0.95     20781
#    macro avg       0.94      0.95      0.94     20781
# weighted avg       0.95      0.95      0.95     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[11231,   593],
#        [  532,  8425]], dtype=int64)

# %%
cross_val_results = cross_val_score(dtc, x, y , cv=kf)
print(f'accuracy of all 10 folds: {cross_val_results}')
print(f'mean accuracy: {cross_val_results.mean()}')
# Out:
# accuracy of all 10 folds: [0.94071793 0.94639592 0.94899432 0.94379752 0.94302214 0.94600577
#  0.94966314 0.94475457 0.94571704 0.94831569]
# mean accuracy: 0.945738403217636

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict = rfc.predict(x_test)

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97     11824
#          1.0       0.97      0.94      0.96      8957
#
#     accuracy                           0.96     20781
#    macro avg       0.96      0.96      0.96     20781
# weighted avg       0.96      0.96      0.96     20781

# %%
confusion_matrix(y_test, y_predict)
# Out:
# array([[11580,   244],
#        [  512,  8445]], dtype=int64)

# %%
cross_val_results = cross_val_score(rfc, x, y , cv=kf)
print(f'accuracy of all 10 folds: {cross_val_results}')
print(f'mean accuracy: {cross_val_results.mean()}')
# Out:
# accuracy of all 10 folds: [0.9637186  0.96410355 0.96275623 0.96362237 0.96217517 0.96188643
#  0.96477382 0.96352262 0.96275265 0.95813282]
# mean accuracy: 0.9627444254018224
